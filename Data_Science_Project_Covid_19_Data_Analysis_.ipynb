# %% [markdown]
# <a href="https://colab.research.google.com/github/ChSuneetha14/ChSuneeetha14/blob/main/Data_Science_Project_Covid_19_Data_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Science life cycle includes all the processes like Business understanding-Data understanding-Data preprocessing-Data exploration-
# Model building-Deployement

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("/content/drive/MyDrive/Worldwide Vaccine Data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            187 non-null    object
#  1   Doses administered per 100 people  187 non-null    int64
#  2   Total doses administered           187 non-null    int64
#  3   % of population vaccinated         187 non-null    float64
#  4   % of population fully vaccinated   187 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 7.4+ KB

# %%
df.columns
# Out:
# Index(['Country', 'Doses administered per 100 people',
#        'Total doses administered', '% of population vaccinated',
#        '% of population fully vaccinated'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Doses administered per 100 people  Total doses administered  \
# count                         187.000000              1.870000e+02
# mean                          124.748663              6.197896e+07
# std                            76.319193              2.867899e+08
# min                             0.000000              1.108300e+04
# 25%                            58.500000              1.666500e+06
# 50%                           128.000000              7.140000e+06
# 75%                           193.000000              2.603253e+07
# max                           315.000000              3.343008e+09
#
#        % of population vaccinated  % of population fully vaccinated
# count                  187.000000                        187.000000
# mean                    55.473262                         50.063102
# std                     27.173945                         26.930214
# min                      0.100000                          0.100000
# ...

# %%
df.corr()
# Out:
#                                    Doses administered per 100 people  \
# Doses administered per 100 people                           1.000000
# Total doses administered                                    0.173603
# % of population vaccinated                                  0.966626
# % of population fully vaccinated                            0.980572
#
#                                    Total doses administered  \
# Doses administered per 100 people                  0.173603
# Total doses administered                           1.000000
# % of population vaccinated                         0.186934
# % of population fully vaccinated                   0.182612
#
#                                    % of population vaccinated  \
# Doses administered per 100 people                    0.966626
# Total doses administered                             0.186934
# % of population vaccinated                           1.000000
# % of population fully vaccinated                     0.984786
#
# ...

# %%
df.head()
# Out:
#        Country  Doses administered per 100 people  Total doses administered  \
# 0  Afghanistan                                 16                   5986139
# 1      Albania                                 99                   2814626
# 2      Algeria                                 32                  13772044
# 3       Angola                                 59                  18756893
# 4    Argentina                                219                  98597241
#
#    % of population vaccinated  % of population fully vaccinated
# 0                        14.0                              12.0
# 1                        45.0                              43.0
# 2                        18.0                              15.0
# 3                        38.0                              20.0
# 4                        91.0                              83.0

# %%
df.tail()
# Out:
#               Country  Doses administered per 100 people  \
# 182           Vietnam                                211
# 183  West Bank & Gaza                                 79
# 184             Yemen                                  2
# 185            Zambia                                 21
# 186          Zimbabwe                                 70
#
#      Total doses administered  % of population vaccinated  \
# 182                 203144374                        83.0
# 183                   3718981                        43.0
# 184                    821853                         2.3
# 185                   3787279                        16.0
# 186                  10313861                        40.0
#
#      % of population fully vaccinated
# 182                              81.0
# 183                              38.0
# 184                               1.4
# 185                              14.0
# 186                              25.0

# %%
df.isnull().sum()
# Out:
# Country                              0
# Doses administered per 100 people    0
# Total doses administered             0
# % of population vaccinated           0
# % of population fully vaccinated     0
# dtype: int64

# %%
sns.relplot(x= 'Country', y='% of population vaccinated', data=df)

# %%
sns.relplot(x= 'Country', y='% of population fully vaccinated', data=df)

# %%
sns.relplot(x= 'Country', y='Total doses administered', data=df)

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['Country', 'Doses administered per 100 people',
#        'Total doses administered', '% of population vaccinated',
#        '% of population fully vaccinated'],
#       dtype='object')

# %%
sns.relplot(x= 'Country', y='Total doses administered', kind='line', data=df)

# %%
sns.relplot(x= 'Country', y='% of population vaccinated', kind='line', data=df)

# %%
Link Desc: https://github.com/sfu-db/covid19-datasets/blob/master/datasets-details/world-bank-indicator.md
